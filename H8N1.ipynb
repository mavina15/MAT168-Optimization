# %% [markdown]
# ![Screenshot 2023-12-02 at 5.35.26 PM.png](data:image/png;base64,...)

# %%
# import libraries
import gurobipy as gp
from gurobipy import GRB

# %%
# create model
model = gp.Model()

# create decision variables
x1 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x1")
x2 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x2")
x3 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x3")
x4 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x4")

# set objective function
model.setObjective(1*x1 + 2*x2 + 1*x3 + 1*x4, GRB.MAXIMIZE)

# add constraints
model.addConstr(2*x1 + 1*x2 + 5*x3 + 1*x4 <= 8, "c1")
model.addConstr(2*x1 + 2*x2 + 4*x4 <= 12, "c2")
model.addConstr(3*x1 + 1*x2 + 2*x3 <= 18, "c3")

# optimize model
model.optimize()

# print optimal solution and optimal value
print("\n")
print("Optimal Solution: x1={}, x2={}, x3={}, x4={}".format(x1.x, x2.x, x3.x, x4.x))
print("Optimal Value: {}".format(model.objVal))
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 3 rows, 4 columns and 10 nonzeros
# Model fingerprint: 0x489813d0
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+01]
# Presolve time: 0.01s
# Presolved: 3 rows, 4 columns, 10 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.0000000e+30   5.500000e+30   7.000000e+00      0s
#        2    1.2400000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.240000000e+01
#
#
# Optimal Solution: x1=0.0, x2=6.0, x3=0.4, x4=0.0
# Optimal Value: 12.4

# %% [markdown]
# ![Screenshot 2023-12-02 at 5.38.35 PM.png](data:image/png;base64,...)

# %%
# create model
model = gp.Model()

# create decision variables
x1 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x1")
x2 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x2")
x3 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x3")
x4 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x4")

# set objective function
model.setObjective(3*x1 + 2*x2 + 1*x3 + 1*x4, GRB.MAXIMIZE)

# add constraints
model.addConstr(2*x1 + 1*x2 + 5*x3 + 1*x4 <= 8, "c1")
model.addConstr(2*x1 + 2*x2 + 4*x4 <= 12, "c2")
model.addConstr(3*x1 + 1*x2 + 2*x3 <= 18, "c3")

# optimize model
model.optimize()

# print optimal solution and optimal value
print("\n")
print("Optimal Solution: x1={}, x2={}, x3={}, x4={}".format(x1.x, x2.x, x3.x, x4.x))
print("Optimal Value: {}".format(model.objVal))
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 3 rows, 4 columns and 10 nonzeros
# Model fingerprint: 0x4ca41a4c
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+01]
# Presolve time: 0.01s
# Presolved: 3 rows, 4 columns, 10 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.0000000e+30   5.500000e+30   9.000000e+00      0s
#        3    1.4000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.400000000e+01
#
#
# Optimal Solution: x1=2.0, x2=4.0, x3=0.0, x4=0.0
# Optimal Value: 14.0

# %% [markdown]
# ![Screenshot 2023-12-02 at 5.39.58 PM.png](data:image/png;base64,...)

# %%
# create model
model = gp.Model()

# create decision variables
x1 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x1")
x2 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x2")
x3 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x3")
x4 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x4")

# set objective function
model.setObjective(1*x1 + 2*x2 + 0.5*x3 + 1*x4, GRB.MAXIMIZE)

# add constraints
model.addConstr(2*x1 + 1*x2 + 5*x3 + 1*x4 <= 8, "c1")
model.addConstr(2*x1 + 2*x2 + 4*x4 <= 12, "c2")
model.addConstr(3*x1 + 1*x2 + 2*x3 <= 18, "c3")

# optimize model
model.optimize()

# print optimal solution and optimal value
print("\n")
print("Optimal Solution: x1={}, x2={}, x3={}, x4={}".format(x1.x, x2.x, x3.x, x4.x))
print("Optimal Value: {}".format(model.objVal))
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 3 rows, 4 columns and 10 nonzeros
# Model fingerprint: 0x0edffa54
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [5e-01, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+01]
# Presolve time: 0.01s
# Presolved: 3 rows, 4 columns, 10 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.5000000e+30   5.500000e+30   6.500000e+00      0s
#        2    1.2200000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.220000000e+01
#
#
# Optimal Solution: x1=0.0, x2=6.0, x3=0.4, x4=0.0
# Optimal Value: 12.2

# %% [markdown]
# ![Screenshot 2023-12-02 at 5.40.24 PM.png](data:image/png;base64,...)

# %%
# create model
model = gp.Model()

# create decision variables
x1 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x1")
x2 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x2")
x3 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x3")
x4 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="x4")

# set objective function
model.setObjective(1*x1 + 2*x2 + 1*x3 + 1*x4, GRB.MAXIMIZE)

# add constraints
model.addConstr(2*x1 + 1*x2 + 5*x3 + 1*x4 <= 8, "c1")
model.addConstr(2*x1 + 2*x2 + 4*x4 <= 26, "c2")
model.addConstr(3*x1 + 1*x2 + 2*x3 <= 18, "c3")

# optimize model
model.optimize()

# print optimal solution and optimal value
print("\n")
print("Optimal Solution: x1={}, x2={}, x3={}, x4={}".format(x1.x, x2.x, x3.x, x4.x))
print("Optimal Value: {}".format(model.objVal))
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 3 rows, 4 columns and 10 nonzeros
# Model fingerprint: 0x7b599e94
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 3e+01]
# Presolve time: 0.01s
# Presolved: 3 rows, 4 columns, 10 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.0000000e+30   5.500000e+30   7.000000e+00      0s
#        3    1.6000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.600000000e+01
#
#
# Optimal Solution: x1=0.0, x2=8.0, x3=0.0, x4=0.0
# Optimal Value: 16.0
